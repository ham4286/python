# %% [markdown]
# <a href="https://colab.research.google.com/github/ham4286/python/blob/main/students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploded = files.upload()
# Out:
#      <input type="file" id="files-b067833d-beb5-4a9d-8625-1e83d22055b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b067833d-beb5-4a9d-8625-1e83d22055b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving student.csv to student.csv

# %%
import pandas as pd
df = pd.read_csv('/student.csv', encoding='euc-kr')

# %%
df.head()
# Out:
#      구분 성별  키(cm)  몸무게(kg)  검사인원수
# 0  만 6세  남  120.5     24.2   1818
# 1  만 6세  여  119.3     22.9   1649
# 2  만 7세  남  125.7     27.1   2896
# 3  만 7세  여  124.5     25.7   2721
# 4  만 8세  남  131.8     31.4   2959

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   구분       26 non-null     object
#  1   성별       26 non-null     object
#  2   키(cm)    26 non-null     float64
#  3   몸무게(kg)  26 non-null     float64
#  4   검사인원수    26 non-null     int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.1+ KB

# %%
df2 = df['키(cm)']
df2.head()
# Out:
# 0    120.5
# 1    119.3
# 2    125.7
# 3    124.5
# 4    131.8
# Name: 키(cm), dtype: float64

# %%
df2 = df[['키(cm)','몸무게(kg)']]
df2.head()
# Out:
#    키(cm)  몸무게(kg)
# 0  120.5     24.2
# 1  119.3     22.9
# 2  125.7     27.1
# 3  124.5     25.7
# 4  131.8     31.4

# %%
df3 = df.loc[:,['성별', '키(cm)', '몸무게(kg)']]
df3.head()
# Out:
#   성별  키(cm)  몸무게(kg)
# 0  남  120.5     24.2
# 1  여  119.3     22.9
# 2  남  125.7     27.1
# 3  여  124.5     25.7
# 4  남  131.8     31.4

# %%
df4 = df.loc[[1,5,9],['성별','키(cm)', '몸무게(kg)']]
df4.head()
# Out:
#   성별  키(cm)  몸무게(kg)
# 1  여  119.3     22.9
# 5  여  130.2     29.0
# 9  여  143.1     38.0

# %%
df.describe()
# Out:
#             키(cm)    몸무게(kg)        검사인원수
# count   26.000000  26.000000    26.000000
# mean   150.323077  47.011538  3185.807692
# std     17.380663  14.988431  1000.170906
# min    119.300000  22.900000  1267.000000
# 25%    136.800000  33.725000  2724.500000
# 50%    156.250000  50.200000  2939.000000
# 75%    160.775000  57.025000  3990.000000
# max    173.500000  70.000000  4587.000000

# %%
df['성별'] == '여'
df['성별'] == '남'
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14     True
# 15    False
# 16     True
# 17    False
# 18     True
# 19    False
# 20     True
# 21    False
# 22     True
# 23    False
# 24     True
# 25    False
# Name: 성별, dtype: bool

# %%
 female = df[df['성별'] == '여']
 female
# Out:
#        구분 성별  키(cm)  몸무게(kg)  검사인원수
# 1    만 6세  여  119.3     22.9   1649
# 3    만 7세  여  124.5     25.7   2721
# 5    만 8세  여  130.2     29.0   2801
# 7    만 9세  여  136.6     33.1   2602
# 9   만 10세  여  143.1     38.0   2644
# 11  만 11세  여  150.1     43.6   2735
# 13  만 12세  여  155.3     48.4   3189
# 15  만 13세  여  158.4     52.0   3651
# 17  만 14세  여  159.7     53.9   3920
# 19  만 15세  여  160.3     55.6   4363
# 21  만 16세  여  160.6     56.8   4587
# 23  만 17세  여  160.8     57.1   4480
# 25  만 18세  여  160.7     56.6   1267

# %%
 male = df[df['성별'] == '남']
 male
# Out:
#        구분 성별  키(cm)  몸무게(kg)  검사인원수
# 0    만 6세  남  120.5     24.2   1818
# 2    만 7세  남  125.7     27.1   2896
# 4    만 8세  남  131.8     31.4   2959
# 6    만 9세  남  137.4     35.6   2779
# 8   만 10세  남  142.7     40.3   2844
# 10  만 11세  남  149.2     45.9   2919
# 12  만 12세  남  157.2     52.0   3456
# 14  만 13세  남  164.0     57.6   3948
# 16  만 14세  남  168.9     62.4   4004
# 18  만 15세  남  171.6     65.4   4525
# 20  만 16세  남  172.8     68.1   4531
# 22  만 17세  남  173.5     69.6   4247
# 24  만 18세  남  173.5     70.0   1296

# %%
# !sudo apt-get install -y fonts-namum
# !sudo fc-cache -fv
# !rm ~/.cache/maplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package fonts-namum
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 2 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NaumTGothic')
plt.rc('axes', unicode_minus = False)

# %%
plt.figure(figsize = (10,5))
plt.scatter(female['구분'], female['키(cm)'])
plt.show()
# Out:
# findfont: Font family ['NaumTGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47564 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47564 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt. figure(figsize = (10,5))
plt.scatter(female['구분'], female['키(cm)'], label = '여학생 키')
plt.scatter(male['구분'], male['키(cm)'], label = '남학생 키')
plt.legend()
plt.xlabel('나이')
plt.ylabel('키(cm)')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47564 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53412 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
